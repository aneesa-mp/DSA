# %% [markdown]
# # **Week 1 - Project Setup and Data Collection**

# %% [markdown]
# Key Variables in the Data:
# Num_of_Loan: Number of loans the customer has.
# Type_of_Loan: Types of loans the customer has (e.g., Auto Loan, Credit-Builder Loan, etc.).
#  Delay_from_due_date: The delay in payment from the due date.
#   Num_of_Delayed_Payment: Number of delayed payments. Changed_Credit_Limit: Change in credit limit. Num_Credit_Inquiries: Number of credit inquiries. Credit_Mix: Diversity of credit types.
#    Outstanding_Debt: Total outstanding debt. Credit_Utilization_Ratio: Ratio of credit used to total available credit.
#    Credit_History_Age: Age of the credit history. Payment_of_Min_Amount: Indicates if the minimum amount is paid or not.
#    Total_EMI_per_month: Total EMI paid per month. Amount_invested_monthly: Amount invested monthly. Payment_Behaviour: Payment behavior (e.g., High_spent_Small_value_payments, Low_spent_Large_value_payments, etc.).
#    Monthly_Balance: Monthly balance. Credit_Score: Credit score category (Good, Standard, Poor).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Load the **Data**

# %%
data=pd.read_csv("/content/drive/MyDrive/credit.csv")

# %%
data
# Out:
#            ID  Customer_ID  Month           Name  Age        SSN Occupation  \
# 0        5634         3392      1  Aaron Maashoh   23  821000265  Scientist
# 1        5635         3392      2  Aaron Maashoh   23  821000265  Scientist
# 2        5636         3392      3  Aaron Maashoh   23  821000265  Scientist
# 3        5637         3392      4  Aaron Maashoh   23  821000265  Scientist
# 4        5638         3392      5  Aaron Maashoh   23  821000265  Scientist
# ...       ...          ...    ...            ...  ...        ...        ...
# 99995  155625        37932      4          Nicks   25   78735990   Mechanic
# 99996  155626        37932      5          Nicks   25   78735990   Mechanic
# 99997  155627        37932      6          Nicks   25   78735990   Mechanic
# 99998  155628        37932      7          Nicks   25   78735990   Mechanic
# 99999  155629        37932      8          Nicks   25   78735990   Mechanic
#
# ...

# %% [markdown]
# # 2. Explore the **Data**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  int64
#  5   SSN                       100000 non-null  int64
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  int64
#  10  Num_Credit_Card           100000 non-null  int64
#  11  Interest_Rate             100000 non-null  int64
#  12  Num_of_Loan               100000 non-null  int64
# ...

# %%
data.describe()
# Out:
#                   ID    Customer_ID          Month            Age  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean    80631.500000   25982.666640       4.500000      33.316340
# std     43301.486619   14340.543051       2.291299      10.764812
# min      5634.000000    1006.000000       1.000000      14.000000
# 25%     43132.750000   13664.500000       2.750000      24.000000
# 50%     80631.500000   25777.000000       4.500000      33.000000
# 75%    118130.250000   38385.000000       6.250000      42.000000
# max    155629.000000   50999.000000       8.000000      56.000000
#
#                 SSN  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  1.000000e+05  100000.000000          100000.000000      100000.000000
# mean   5.004617e+08   50505.123449            4197.270835           5.368820
# std    2.908267e+08   38299.422093            3186.432497           2.593314
# ...

# %%
data.shape
# Out:
# (100000, 28)

# %% [markdown]
# **Identify and handle missing values in your dataset.**

# %%
data.isnull().sum()
# Out:
# ID                          0
# Customer_ID                 0
# Month                       0
# Name                        0
# Age                         0
# SSN                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# Credit_Score                0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
num_data=data.select_dtypes(include=['int64','float64'])
num_data#Numerical data
# Out:
#            ID  Customer_ID  Month  Age        SSN  Annual_Income  \
# 0        5634         3392      1   23  821000265       19114.12
# 1        5635         3392      2   23  821000265       19114.12
# 2        5636         3392      3   23  821000265       19114.12
# 3        5637         3392      4   23  821000265       19114.12
# 4        5638         3392      5   23  821000265       19114.12
# ...       ...          ...    ...  ...        ...            ...
# 99995  155625        37932      4   25   78735990       39628.99
# 99996  155626        37932      5   25   78735990       39628.99
# 99997  155627        37932      6   25   78735990       39628.99
# 99998  155628        37932      7   25   78735990       39628.99
# 99999  155629        37932      8   25   78735990       39628.99
#
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0                1824.843333                  3                4
# ...

# %% [markdown]
# ***Identify categorical and numerical variable***

# %%
cat_data=data.select_dtypes(include=['object'])
cat_data#Categorical data
# Out:
#                 Name Occupation  \
# 0      Aaron Maashoh  Scientist
# 1      Aaron Maashoh  Scientist
# 2      Aaron Maashoh  Scientist
# 3      Aaron Maashoh  Scientist
# 4      Aaron Maashoh  Scientist
# ...              ...        ...
# 99995          Nicks   Mechanic
# 99996          Nicks   Mechanic
# 99997          Nicks   Mechanic
# 99998          Nicks   Mechanic
# 99999          Nicks   Mechanic
#
#                                             Type_of_Loan Credit_Mix  \
# 0      Auto Loan, Credit-Builder Loan, Personal Loan,...       Good
# 1      Auto Loan, Credit-Builder Loan, Personal Loan,...       Good
# 2      Auto Loan, Credit-Builder Loan, Personal Loan,...       Good
# 3      Auto Loan, Credit-Builder Loan, Personal Loan,...       Good
# 4      Auto Loan, Credit-Builder Loan, Personal Loan,...       Good
# ...                                                  ...        ...
# 99995                        Auto Loan, and Student Loan       Good
# ...

# %%
freqgraph=data.select_dtypes(include=['int','float64'])
freqgraph.hist(figsize=(20,20));

# %% [markdown]
# #Outliers **Detection**

# %%
#Outliers Detection
new_col={'Annual_Income','Monthly_Inhand_Salary','Total_EMI_per_month','Amount_invested_monthly','Monthly_Balance'}
for i in new_col:
    plt.figure()
    plt.boxplot(data[i])
    plt.title(i)

# %% [markdown]
# Outliers are genuine outliers.so,outliers are not treated

# %% [markdown]
# **Label Encoding**

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  int64
#  5   SSN                       100000 non-null  int64
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  int64
#  10  Num_Credit_Card           100000 non-null  int64
#  11  Interest_Rate             100000 non-null  int64
#  12  Num_of_Loan               100000 non-null  int64
# ...

# %%
cat_data=data.select_dtypes(include=['object'])
cat_data#Categorical data
# Out:
#                 Name Occupation  \
# 0      Aaron Maashoh  Scientist
# 1      Aaron Maashoh  Scientist
# 2      Aaron Maashoh  Scientist
# 3      Aaron Maashoh  Scientist
# 4      Aaron Maashoh  Scientist
# ...              ...        ...
# 99995          Nicks   Mechanic
# 99996          Nicks   Mechanic
# 99997          Nicks   Mechanic
# 99998          Nicks   Mechanic
# 99999          Nicks   Mechanic
#
#                                             Type_of_Loan Credit_Mix  \
# 0      Auto Loan, Credit-Builder Loan, Personal Loan,...       Good
# 1      Auto Loan, Credit-Builder Loan, Personal Loan,...       Good
# 2      Auto Loan, Credit-Builder Loan, Personal Loan,...       Good
# 3      Auto Loan, Credit-Builder Loan, Personal Loan,...       Good
# 4      Auto Loan, Credit-Builder Loan, Personal Loan,...       Good
# ...                                                  ...        ...
# 99995                        Auto Loan, and Student Loan       Good
# ...

# %%
data['Type_of_Loan']=le.fit_transform(data['Type_of_Loan'])

# %%
data['Occupation']=le.fit_transform(data['Occupation'])

# %%
data['Type_of_Loan']=le.fit_transform(data['Type_of_Loan'])

# %%
data['Credit_Mix']=le.fit_transform(data['Credit_Mix'])

# %%
data['Payment_of_Min_Amount']=le.fit_transform(data['Payment_of_Min_Amount'])

# %%
data['Payment_Behaviour']=le.fit_transform(data['Payment_Behaviour'])

# %%
data['Credit_Score']=le.fit_transform(data['Credit_Score'])

# %%
data['Name']=le.fit_transform(data['Name'])

# %%
data
# Out:
#            ID  Customer_ID  Month  Name  Age        SSN  Occupation  \
# 0        5634         3392      1    11   23  821000265          12
# 1        5635         3392      2    11   23  821000265          12
# 2        5636         3392      3    11   23  821000265          12
# 3        5637         3392      4    11   23  821000265          12
# 4        5638         3392      5    11   23  821000265          12
# ...       ...          ...    ...   ...  ...        ...         ...
# 99995  155625        37932      4  6508   25   78735990           9
# 99996  155626        37932      5  6508   25   78735990           9
# 99997  155627        37932      6  6508   25   78735990           9
# 99998  155628        37932      7  6508   25   78735990           9
# 99999  155629        37932      8  6508   25   78735990           9
#
#        Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0           19114.12            1824.843333                  3  ...
# ...

# %% [markdown]
# **Scaling/Normalization**

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
x_sc=sc.fit_transform(data)
x_sc=pd.DataFrame(x_sc)

# %%
x_sc.describe()
# Out:
#                  0             1              2             3             4   \
# count  1.000000e+05  1.000000e+05  100000.000000  1.000000e+05  1.000000e+05
# mean  -3.637979e-17  3.467449e-17       0.000000  1.323031e-16  3.050715e-16
# std    1.000005e+00  1.000005e+00       1.000005  1.000005e+00  1.000005e+00
# min   -1.731993e+00 -1.741691e+00      -1.527525 -1.742330e+00 -1.794405e+00
# 25%   -8.659965e-01 -8.589792e-01      -0.763763 -8.634183e-01 -8.654482e-01
# 50%    0.000000e+00 -1.434169e-02       0.000000 -3.053570e-03 -2.938663e-02
# 75%    8.659965e-01  8.648484e-01       0.763763  8.725093e-01  8.066749e-01
# max    1.731993e+00  1.744457e+00       1.527525  1.735879e+00  2.107215e+00
#
#                  5             6             7             8             9   \
# count  1.000000e+05  1.000000e+05  1.000000e+05  1.000000e+05  1.000000e+05
# mean   9.663381e-17 -4.121148e-18 -1.193712e-16 -5.542233e-17 -1.426770e-16
# ...

# %% [markdown]
# **correlation**

# %%
plt.figure(figsize=(20,20))
heatmap=sns.heatmap(data.corr(),annot=True,cmap='YlGnBu')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Week 2 - Model Development and Training**

# %%
y=data['Credit_Score']
X=data.drop(['Credit_Score'],axis=1)

# %% [markdown]
# Data **Split**

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.25)

# %% [markdown]
# Model Training

# %% [markdown]
# # **SVM**

# %%
from sklearn.svm import SVC
sv_clf=SVC()
sv_clf.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_pred=sv_clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
print('ACCURACY IS:',accuracy_score(y_test,y_pred))
# Out:
# ACCURACY IS: 0.5306

# %% [markdown]
# Accuracy of SVM is 53 percentage

# %% [markdown]
# # #Accuracy and confusion matrix

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[    0     0  4422]
#  [    0     0  7313]
#  [    0     0 13265]]

# %% [markdown]
# # Decision **Tree**

# %%
from sklearn.tree import DecisionTreeClassifier
dt_clf=DecisionTreeClassifier()
dt_clf.fit(X_train,y_train)
y_pred=dt_clf.predict(X_test)

# %%
print('ACCURACY IS:',accuracy_score(y_test,y_pred))
# Out:
# ACCURACY IS: 0.75472

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[ 3073   156  1193]
#  [  131  5361  1821]
#  [ 1184  1647 10434]]

# %% [markdown]
# Accuracy of Decision tree is 75.4 percentage

# %% [markdown]
# # *Random Forest*

# %%
from sklearn.ensemble import RandomForestClassifier
rf_clf=RandomForestClassifier()
model=rf_clf.fit(X_train,y_train)

# %%
y_pred=rf_clf.predict(X_test)

# %%
print('Accuracy is:',accuracy_score(y_test,y_pred))
# Out:
# Accuracy is: 0.84076

# %% [markdown]
# Accuracy of Random forest is 84 percentage

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[ 3623    14   785]
#  [   12  6353   948]
#  [  820  1402 11043]]

# %% [markdown]
# # **Cross validation of Random forest**

# %%
from sklearn.model_selection import cross_val_score

# %%
cv_scores = cross_val_score(model, X, y, cv=5)

# %%
print(f"Cross-validation scores: {cv_scores}")
print(f"Mean cross-validation score: {cv_scores.mean()}")
# Out:
# Cross-validation scores: [0.6935  0.7008  0.7045  0.69675 0.5662 ]
# Mean cross-validation score: 0.67235

# %% [markdown]
# KFOLD

# %%
from sklearn.model_selection import KFold

# %%
kfold_validator=KFold(5)

# %%
for train_index,test_index in kfold_validator.split(X,y):
  print('Training index:',train_index)
  print('Testing index:',test_index)
# Out:
# Training index: [20000 20001 20002 ... 99997 99998 99999]
# Testing index: [    0     1     2 ... 19997 19998 19999]
# Training index: [    0     1     2 ... 99997 99998 99999]
# Testing index: [20000 20001 20002 ... 39997 39998 39999]
# Training index: [    0     1     2 ... 99997 99998 99999]
# Testing index: [40000 40001 40002 ... 59997 59998 59999]
# Training index: [    0     1     2 ... 99997 99998 99999]
# Testing index: [60000 60001 60002 ... 79997 79998 79999]
# Training index: [    0     1     2 ... 79997 79998 79999]
# Testing index: [80000 80001 80002 ... 99997 99998 99999]

# %%
from sklearn.model_selection import cross_val_score
cv_result=cross_val_score(model,X,y,cv=kfold_validator)

# %%
cv_result
# Out:
# array([0.69615, 0.7039 , 0.70805, 0.70415, 0.7102 ])

# %%
cv_result.mean()
# Out:
# 0.70449

# %% [markdown]
# Stratified

# %%
from sklearn.model_selection import StratifiedKFold
strat_validator=StratifiedKFold(n_splits=5)

# %%
for train_index,test_index in strat_validator.split(X,y):
  print('Training index:',train_index)
  print('Testing index:',test_index)
# Out:
# Training index: [19927 19944 19945 ... 99997 99998 99999]
# Testing index: [    0     1     2 ... 20044 20045 20046]
# Training index: [    0     1     2 ... 99997 99998 99999]
# Testing index: [19927 19944 19945 ... 40326 40327 40328]
# Training index: [    0     1     2 ... 99997 99998 99999]
# Testing index: [39482 39483 39484 ... 60187 60188 60189]
# Training index: [    0     1     2 ... 99997 99998 99999]
# Testing index: [59586 59587 59588 ... 80769 80770 80773]
# Training index: [    0     1     2 ... 80769 80770 80773]
# Testing index: [79087 79088 79089 ... 99997 99998 99999]

# %%
skr_cv_resulit=cross_val_score(log_reg,X,y,cv=strat_validator)

# %%
skr_cv_resulit
# Out:
# array([0.53175, 0.53175, 0.5317 , 0.53175, 0.53175])

# %%
skr_cv_resulit.mean()
# Out:
# 0.5317399999999999

# %% [markdown]
# Model Performance Summary:
# Decision Tree Classifier:
#
# Accuracy: 75.4%
# Confusion Matrix and Classification Report indicate decent performance but may overfit the training data due to the inherent nature of decision trees.

# %% [markdown]
# Random Forest Classifier:
#
# Accuracy: 84%
# Confusion Matrix and Classification Report show the best performance among the three models. Random Forest typically provides better generalization due to its ensemble nature, reducing the risk of overfitting.

# %% [markdown]
# Support Vector Machine (SVM):
#
# Accuracy: 53%
# Confusion Matrix and Classification Report indicate poor performance. SVMs can be sensitive to the scaling and selection of features, and they might not be the best choice for this specific dataset.

# %% [markdown]
# Conclusion:Random Forest Classifier:
#
# The Random Forest classifier achieved the highest accuracy at 84%, indicating it is the most suitable model for this dataset among the three tested.
# The ensemble nature of Random Forest helps to handle the complexities and variabilities in the data better than single estimators like Decision Trees.

# %% [markdown]
# Decision Tree Classifier:
#
# The Decision Tree classifier performed reasonably well with an accuracy of 75.4%. It is simpler and easier to interpret than Random Forest but might overfit on the training data due to its nature of capturing all details.
# While it can be a good model, it lacks the robustness provided by the Random Forest classifier.

# %% [markdown]
# Support Vector Machine (SVM):
#
# The SVM model underperformed with an accuracy of 53%, suggesting that it might not be well-suited for this dataset or that it requires more hyperparameter tuning and feature engineering.
# SVMs are powerful but can struggle with larger and more complex datasets without careful preprocessing and tuning.

# %% [markdown]
# In summary, the Random Forest classifier is the recommended model for this credit score classification task due to its superior accuracy and robustness, with Decision Trees as a simpler alternative for interpretability. Further improvements can be achieved through hyperparameter tuning and enhanced feature engineering.

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=.2)

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression()

# %%
log_reg.fit(X_train,y_train)
log_pred=log_reg.predict(X_test)

# %%
log_pred
# Out:
# array([2, 2, 2, ..., 2, 2, 2])

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# %%
confusion_matrix(y_test,log_pred)
# Out:
# array([[    0,     0,  3527],
#        [    0,     0,  5874],
#        [    0,     0, 10599]])

# %% [markdown]
# Cross Validation

# %%
data['Credit_Score'].value_counts()
# Out:
# Credit_Score
# 2    53174
# 1    28998
# 0    17828
# Name: count, dtype: int64

# %% [markdown]
# Hold out method

# %%
log_score=log_reg.score(X_test,y_test)

# %%
log_score
# Out:
# 0.52995

# %% [markdown]
# # KFOLD

# %%
from sklearn.model_selection import KFold

# %%
kfold_validator=KFold(10)

# %%
for train_index,test_index in kfold_validator.split(X,y):
  print('Training index:',train_index)
  print('Testing index:',test_index)
# Out:
# Training index: [10000 10001 10002 ... 99997 99998 99999]
# Testing index: [   0    1    2 ... 9997 9998 9999]
# Training index: [    0     1     2 ... 99997 99998 99999]
# Testing index: [10000 10001 10002 ... 19997 19998 19999]
# Training index: [    0     1     2 ... 99997 99998 99999]
# Testing index: [20000 20001 20002 ... 29997 29998 29999]
# Training index: [    0     1     2 ... 99997 99998 99999]
# Testing index: [30000 30001 30002 ... 39997 39998 39999]
# Training index: [    0     1     2 ... 99997 99998 99999]
# Testing index: [40000 40001 40002 ... 49997 49998 49999]
# Training index: [    0     1     2 ... 99997 99998 99999]
# Testing index: [50000 50001 50002 ... 59997 59998 59999]
# Training index: [    0     1     2 ... 99997 99998 99999]
# Testing index: [60000 60001 60002 ... 69997 69998 69999]
# Training index: [    0     1     2 ... 99997 99998 99999]
# Testing index: [70000 70001 70002 ... 79997 79998 79999]
# ...

# %%
from sklearn.model_selection import cross_val_score
cv_result=cross_val_score(log_reg,X,y,cv=kfold_validator)

# %%
cv_result
# Out:
# array([0.5201, 0.5404, 0.5313, 0.5198, 0.5295, 0.538 , 0.5272, 0.5416,
#        0.5342, 0.5353])

# %%
from sklearn.model_selection import StratifiedKFold
strat_validator=StratifiedKFold(n_splits=10)

# %%
for train_index,test_index in strat_validator.split(X,y):
  print('Training index:',train_index)
  print('Testing index:',test_index)
# Out:
# Training index: [ 9635  9636  9639 ... 99997 99998 99999]
# Testing index: [    0     1     2 ... 10232 10233 10234]
# Training index: [    0     1     2 ... 99997 99998 99999]
# Testing index: [ 9635  9636  9639 ... 20045 20046 20047]
# Training index: [    0     1     2 ... 99997 99998 99999]
# Testing index: [19926 19927 19944 ... 30067 30068 30069]
# Training index: [    0     1     2 ... 99997 99998 99999]
# Testing index: [29862 29863 29918 ... 40326 40327 40328]
# Training index: [    0     1     2 ... 99997 99998 99999]
# Testing index: [39482 39483 39484 ... 50318 50320 50321]
# Training index: [    0     1     2 ... 99997 99998 99999]
# Testing index: [49484 49485 49486 ... 60187 60188 60189]
# Training index: [    0     1     2 ... 99997 99998 99999]
# Testing index: [59586 59587 59588 ... 70299 70300 70301]
# Training index: [    0     1     2 ... 99997 99998 99999]
# Testing index: [69533 69534 69535 ... 80770 80773 80774]
# ...

# %%
skr_cv_resulit=cross_val_score(log_reg,X,y,cv=strat_validator)

# %%
skr_cv_resulit
# Out:
# array([0.5318, 0.5318, 0.5317, 0.5317, 0.5317, 0.5317, 0.5317, 0.5317,
#        0.5318, 0.5318])

# %%
skr_cv_resulit.mean()
# Out:
# 0.5317400000000001

# %% [markdown]
# From the above result random forest perform well and stratified cross validation give better reult
